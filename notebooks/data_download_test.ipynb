# %%
from google.colab import drive
drive.mount('/content/drive')
import os
# Out:
# Mounted at /content/drive

# %%
# !ls
# %cd drive/MyDrive/github_repos/regen_pgc_ssl/data/raw/
# Out:
# drive  sample_data
# /content/drive/MyDrive/github_repos/regen_pgc_ssl/data/raw

# %%
import os
if os.path.exists('./cropandweed-dataset'):
  print(True)
  # !rm -rf ./cropandweed-dataset/
# Download crop and weed dataset
# !git clone https://github.com/cropandweed/cropandweed-dataset.git
# %cd cropandweed-dataset
# !python cnw/setup.py
# Out:
# Cloning into 'cropandweed-dataset'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 44 (delta 11), reused 32 (delta 7), pack-reused 0
# Receiving objects: 100% (44/44), 7.87 MiB | 22.14 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# /content/drive/MyDrive/github_repos/regen_pgc_ssl/data/raw/cropandweed-dataset/cropandweed-dataset
# downloading and extracting files:  40% 2/5 [10:01<15:01, 300.54s/it]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/github_repos/regen_pgc_ssl/data/raw/cropandweed-dataset/cropandweed-dataset/cnw/setup.py", line 53, in <module>
#     main()
#   File "/content/drive/MyDrive/github_repos/regen_pgc_ssl/data/raw/cropandweed-dataset/cropandweed-dataset/cnw/setup.py", line 49, in main
#     setup(args.data_root, args.with_mapping)
# ...

# %%
if os.path.exists('./grass-clover-dataset'):
  print(True)
  # !rm -rf ./grass-clover-datatset
os.mkdir('./grass-clover-dataset')
# %cd ./grass-clover-dataset
# !wget -q https://vision.eng.au.dk/?download=/data/GrassClover/synthetic_images.zip -cO synthetic_images.zip
# Out:
# /content/drive/MyDrive/github_repos/regen_pgc_ssl/data/raw/grass-clover-dataset/grass-clover-dataset
# ^C
